# %%
import pandas as pd

# %%
pd.read_csv("file1.csv")
# Out:
#     a   b   c     d Message
# 0   2   3  23  22.0   every
# 1   3   4  11  22.0   thing
# 2  34  12  23  22.0      is
# 3   3   1  12   1.0   going
# 4   2   4   4  23.0      to
# 5  12  32  34  23.0      be
# 6   1  12  21   NaN      ok

# %%
df=pd.read_csv("file1.csv",header=None)

# %% [markdown]
# ### writing data to csv file

# %%
df.to_csv('file2.csv')

# %% [markdown]
# ### Excel files

# %%
pd.read_excel('Excel_Sample.xlsx',"Sheet1")
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel("Example3.xlsx","Sheet1")

# %% [markdown]
# ###  HTMl files

# %%
x=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population")

# %%
x[0].head()
# Out:
#   Rank Country (or dependent territory)  Population % of worldpopulation  \
# 0    1                         China[b]  1402872320                  NaN
# 1    2                         India[c]  1362872030                  NaN
# 2    3                 United States[d]   329776550                  NaN
# 3    4                        Indonesia   266911900                  NaN
# 4    5                      Pakistan[e]   220892331                  NaN
#
#           Date                         Source
# 0  30 May 2020   National population clock[3]
# 1  30 May 2020   National population clock[4]
# 2  30 May 2020   National population clock[5]
# 3   1 Jul 2019  National annual projection[6]
# 4   1 Jul 2020               UN Projection[2]

# %%
len(x)
# Out:
# 2

# %%
x[1]
# Out:
#        vteLists of countries by population statistics  \
# 0                                              Global
# 1                               Continents/subregions
# 2                                    Intercontinental
# 3                                  Cities/urban areas
# 4                                     Past and future
# 5                                  Population density
# 6                                   Growth indicators
# 7                                  Other demographics
# 8                                              Health
# 9                            Education and innovation
# 10                                           Economic
# 11  List of international rankings List of top int...
#
#      vteLists of countries by population statistics.1
# 0        Current population Demographics of the world
# 1   Africa Antarctica Asia Europe North America Ca...
# 2   Americas Arab world Commonwealth of Nations Eu...
# ...

# %%
z=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area")

# %%
z[0].head()
# Out:
#    Rank Sovereign state/dependency         Total in km2 (mi2)  \
# 0   NaN                      World  510,072,000 (196,940,000)
# 1   1.0                     Russia     17,098,246 (6,601,670)
# 2   NaN                 Antarctica     14,000,000 (5,400,000)
# 3   2.0                     Canada      9,984,670 (3,855,100)
# 4   3.0                      China      9,596,961 (3,705,407)
#
#           Land in km2 (mi2)         Water in km2 (mi2) % water  \
# 0  148,940,000 (57,510,000)  361,132,000 (139,434,000)    70.8
# 1    16,377,742 (6,323,482)          720,500 (278,200)    4.21
# 2    14,000,000 (5,400,000)                      0 (0)       0
# 3     9,093,507 (3,511,023)          891,163 (344,080)    8.93
# 4     9,326,410 (3,600,950)          270,550 (104,460)    2.82
#
#                                                Notes
# 0                                                NaN
# 1  Largest country in the world (10.995% of the w...
# ...
